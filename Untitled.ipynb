# %%
# Python
import pandas as pd
from fbprophet import Prophet

# %%
# Python
df =  pd.read_csv('Merged_Data_old2.csv', header=0)
df.head()
# Out:
#         TIME_STAMP  TEMPERATURE_Out  GAS_Out  HUMIDITY_Out  PRESSURE_Out  \
# 0  5/12/2019 18:58               75   364884          84.9         975.0
# 1  5/12/2019 18:59               75   362475          84.6         975.0
# 2  5/12/2019 19:00               75   362874          84.2         975.0
# 3  5/12/2019 19:01               75   362475          84.4         975.0
# 4  5/12/2019 19:02               75   362874          84.4         975.0
#
#    ALTITUDE_Out  id_In  TEMPERATURE_In   GAS_In  HUMIDITY_In  PRESSURE_In  \
# 0         323.2      2              74  6049661         35.9        972.9
# 1         323.3      3              74  5851528         35.9        972.9
# 2         323.4      4              74  5636172         36.2        972.9
# 3         323.5      5              74  5441624         37.3        972.9
# 4         323.5      6              74  5219085         37.1        972.9
#
#    ALTITUDE_In
# 0        341.2
# 1        341.3
# 2        341.4
# ...

# %%
df=df.dropna()

# %%
indoor =
